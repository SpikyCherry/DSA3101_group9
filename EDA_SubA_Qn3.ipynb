# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
file_path = '/content/gdrive/My Drive/DSA3101/BankChurners.csv'
data = pd.read_csv(file_path, index_col = 0)
# OR，index_col = "Date"

# %%
data
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
# ...                      ...           ...    ...              ...
# 772366833  Existing Customer            50      M                2
# 710638233  Attrited Customer            41      M                2
# 716506083  Attrited Customer            44      F                1
# 717406983  Attrited Customer            30      M                2
# 714337233  Attrited Customer            43      F                2
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
data_section = data.iloc[:,1:6]
data_section
# Out:
#            Customer_Age Gender  Dependent_count Education_Level Marital_Status
# CLIENTNUM
# 768805383            45      M                3     High School        Married
# 818770008            49      F                5        Graduate         Single
# 713982108            51      M                3        Graduate        Married
# 769911858            40      F                4     High School        Unknown
# 709106358            40      M                3      Uneducated        Married
# ...                 ...    ...              ...             ...            ...
# 772366833            50      M                2        Graduate         Single
# 710638233            41      M                2         Unknown       Divorced
# 716506083            44      F                1     High School        Married
# 717406983            30      M                2        Graduate        Unknown
# 714337233            43      F                2        Graduate        Married
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10127 entries, 768805383 to 714337233
# Data columns (total 22 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   Attrition_Flag                                                                                                                      10127 non-null  object
#  1   Customer_Age                                                                                                                        10127 non-null  int64
#  2   Gender                                                                                                                              10127 non-null  object
# ...

# %% [markdown]
# ## Pie Charts for categorical data

# %%
gender_counts = data['Gender'].value_counts()
education_counts = data['Education_Level'].value_counts()
married_counts = data['Marital_Status'].value_counts()

# %%
colors = ['lightblue','lightcoral']
explode = [0.1, 0]
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x787713920410>,
# ...
#  [Text(-0.6842624092213119, -0.9857915374594397, 'F'),
#   Text(0.6272405417862027, 0.9036422426711531, 'M')],
#  [Text(-0.3991530720457652, -0.5750450635180064, '52.9%'),
#   Text(0.342131204610656, 0.49289576872971985, '47.1%')])

# %%
plt.pie(education_counts, labels=education_counts.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x787713638ed0>,
# ...
#  [Text(-1.059489630202798, -0.29577309460587914, 'Graduate'),
#   Text(0.3211574068265897, -1.052073153369299, 'High School'),
#   Text(1.0824588400288595, -0.1956600614417161, 'Unknown'),
#   Text(0.802081446122541, 0.7527717806785623, 'Uneducated'),
#   Text(0.04569429936808739, 1.0990505134002075, 'College'),
#   Text(-0.4613290857045435, 0.9985867386877366, 'Post-Graduate'),
#   Text(-0.7358125341746272, 0.8176673617991079, 'Doctorate')],
#  [Text(-0.5779034346560716, -0.16133077887593406, '30.9%'),
#   Text(0.175176767359958, -0.5738580836559812, '19.9%'),
#   Text(0.590432094561196, -0.10672366987729968, '15.0%'),
#   Text(0.43749897061229504, 0.41060278946103396, '14.7%'),
#   Text(0.024924163291684027, 0.5994820982182949, '10.0%'),
#   Text(-0.2516340467479328, 0.5446836756478562, '5.1%'),
#   Text(-0.40135229136797845, 0.4460003791631497, '4.5%')])

# %%
plt.pie(married_counts, labels= married_counts.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7877135fa9d0>,
# ...
#  [Text(-0.8004448174835155, -0.7545118250655729, 'Married'),
#   Text(1.0536052202178117, 0.3160949856131492, 'Single'),
#   Text(-0.19284239436560488, 1.0829643627263739, 'Unknown'),
#   Text(-0.6574623229232885, 0.881897552971043, 'Divorced')],
#  [Text(-0.4366062640819175, -0.41155190458122154, '46.3%'),
#   Text(0.5746937564824426, 0.17241544669808134, '38.9%'),
#   Text(-0.10518676056305719, 0.5907078342143857, '7.4%'),
#   Text(-0.3586158125036119, 0.48103502889329613, '7.4%')])

# %%
attrition_counts = data['Attrition_Flag'].value_counts()
plt.pie(attrition_counts, labels= attrition_counts.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x78771323aad0>,
# ...
#  [Text(0.39566098647663867, -1.026378284932185, 'Existing Customer'),
#   Text(-0.3956610345248728, 1.0263782664099566, 'Attrited Customer')],
#  [Text(0.21581508353271198, -0.5598427008721008, '83.9%'),
#   Text(-0.2158151097408397, 0.5598426907690671, '16.1%')])

# %%
income_counts = data['Income_Category'].value_counts()
plt.pie(income_counts, labels= income_counts.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x787712f11fd0>,
# ...
#  [Text(-1.0103353464167542, -0.43499711238229827, 'Less than $40K'),
#   Text(0.5232585913714728, -0.9675745173142698, '$40K - $60K'),
#   Text(1.098956138168166, -0.04791039952359583, '$80K - $120K'),
#   Text(0.7113703685399216, 0.839018592620793, '$60K - $80K'),
#   Text(-0.08422297244707778, 1.0967709382146205, 'Unknown'),
#   Text(-0.6631934350609309, 0.877595845302428, '$120K +')],
#  [Text(-0.5510920071364113, -0.2372711522085263, '35.2%'),
#   Text(0.2854137771117124, -0.5277679185350562, '17.7%'),
#   Text(0.5994306208189997, -0.026132945194688634, '15.2%'),
#   Text(0.38802020102177537, 0.457646505065887, '13.8%'),
#   Text(-0.045939803152951514, 0.5982386935716111, '11.0%'),
#   Text(-0.3617418736695986, 0.4786886428922334, '7.2%')])

# %%
card_counts = data['Card_Category'].value_counts()
plt.pie(card_counts, labels= card_counts.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7877137ed590>,
# ...
#  [Text(0.6729528729258643, -0.8701347199260732, 'Blue'),
#   Text(-0.6356540921166466, 0.8977437692211302, 'Silver'),
#   Text(-0.8074577785540277, 0.7470019650928604, 'Gold'),
#   Text(-0.8382458054826416, 0.7122808221416309, 'Platinum')],
#  [Text(0.3670652034141077, -0.4746189381414944, '93.2%'),
#   Text(-0.3467204138818072, 0.4896784195751619, '5.5%'),
#   Text(-0.44043151557492416, 0.40745561732337837, '1.1%'),
#   Text(-0.45722498480871354, 0.3885168120772532, '0.2%')])

# %% [markdown]
# ## Violin Plots to examine the data distributions

# %%
plt.violinplot(data['Total_Trans_Amt'], showmeans=True, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x7877134101d0>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x787712fbff10>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7877133e02d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x787713034c50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7877133e31d0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x78771689b8d0>}

# %%
plt.violinplot(data['Total_Revolving_Bal'], showmeans=True, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x787713520c90>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x7877133fb910>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7877135bff90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x787713bb5a10>,
#  'cbars': <matplotlib.collections.LineCollection at 0x78771365aa50>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7877136585d0>}

# %%
plt.violinplot(data['Credit_Limit'], showmeans=True, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x787715cb86d0>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x787712fd6210>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x78771379b910>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7877136d5d90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x78771356b450>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x78771332e650>}

# %% [markdown]
# ## Histograms to examine frequency

# %%
plt.hist(data['Credit_Limit'], bins=20, color='skyblue', edgecolor='white')
plt.xlabel('Credit Limit')
# Out:
# Text(0.5, 0, 'Credit Limit')

# %%
plt.hist(data['Total_Trans_Ct'], bins=20, color='skyblue', edgecolor='white')
plt.xlabel('Total Transactions Count')
# Out:
# Text(0.5, 0, 'Total Transactions Count')

# %%
plt.hist(data['Months_on_book'], bins=20, color='skyblue', edgecolor='white')
plt.xlabel('Months_on_book')
# Out:
# Text(0.5, 0, 'Months_on_book')

# %%
plt.hist(data['Customer_Age'], bins=20, color='skyblue', edgecolor='white')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(data['Avg_Open_To_Buy'],color='skyblue', edgecolor='white')
plt.xlabel('Avg_Open_To_Buy')
# similarly check again
# Out:
# Text(0.5, 0, 'Avg_Open_To_Buy')

# %% [markdown]
# ### Some werid results of the historgrams, need to check data information again

# %%
plt.hist(data['Contacts_Count_12_mon'],color='skyblue', edgecolor='white')
plt.xlabel('Contacts_Count_12_mon')
# similarly check again
# Out:
# Text(0.5, 0, 'Contacts_Count_12_mon')

# %%
plt.hist(data['Total_Relationship_Count'],color='skyblue', edgecolor='white')
plt.xlabel('Total_Relationship_Count')
# check again, weird results
# Out:
# Text(0.5, 0, 'Total_Relationship_Count')

# %%
plt.hist(data['Months_Inactive_12_mon'],color='skyblue', edgecolor='white')
plt.xlabel('Months_Inactive_12_mon')
# similarly check again
# Out:
# Text(0.5, 0, 'Months_Inactive_12_mon')

# %% [markdown]
# ## Checking data correlations

# %%
plt.plot(data['Total_Ct_Chng_Q4_Q1'], data['Total_Amt_Chng_Q4_Q1'], 'o', color='skyblue')
